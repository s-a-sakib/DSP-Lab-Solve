# %% [markdown]
# ## Q3. Show that the highest rate of oscillation in a discrete-time sinusoidal is obtained
# ## when ω=π.

# %% [markdown]
# 🧠 Theory:
# A discrete-time sinusoid is defined as:
#
#     x[n]=cos(ωn+ϕ)
# Where:
#     ω: normalized angular frequency in radians/sample
#     n: sample index
#     ϕ: phase offset
#
# In discrete-time signals, frequencies are periodic with period
# 2π. The number of zero crossings per unit time increases with
# ω, and the maximum alternation (highest oscillation) happens when:
# ω=π
# because:
# x[n]=cos(πn)=(−1)^n
#
# This alternates between +1 and -1 — the fastest possible rate of change in a discrete signal (every sample changes sign).

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(1, 10, 1)
omega1 = np.pi
omega2 = 0.5 * np.pi

wave1 = np.cos(n * omega1)
wave2 = np.cos(n * omega2)

wave3 = wave1 + wave2

plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.stem(n, wave1, 'r-', label='omega = pi')
plt.title('Cosine Waves with Different Frequencies')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 1, 2)
plt.stem(n, wave2, 'g-', label='omega = 0.5 * pi')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
