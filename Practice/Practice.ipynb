# %%
import numpy as np
import matplotlib.pyplot as plt

def unit_step(n):
    return np.where(n >= 0, 1, 0)

def unit_ramp(n):
    return np.where(n >= 0, n, 0)

def exponential(n, a = 0.5):
    return np.exp(a * n)

def sine(n, f = 1):
    return np.sin(2 * np.pi * f * n / 10)

def cosine(n, f = 1):
    return np.cos(2 * np.pi * f * n /10)

n = np.arange(-10, 11, 1)

signals = {
    "Unit Step" : unit_step(n),
    "Unit Ramp" : unit_ramp(n),
    "Exponential" : exponential(n),
    "Sine" : sine(n),
    "Cosine" : cosine(n)
}

plt.figure(figsize=(12, 8))
for name, function in signals.items():
    plt.subplot(3, 2, list(signals.keys()).index(name) + 1)
    plt.stem(n, function, label=name)
    plt.title(name)
    plt.xlabel('n')
    plt.ylabel('Amplitude')
    plt.grid()
    plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def signals(n , f = 10):
    return np.sin(2 * np.pi * n * f)

n = np.linspace(0, 1, 1000)
n_sample = np.arange(0 , 1 , 1/ 50)
n_alisging = np.arange(0, 1, 1 / 15)

plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(n, signals(n), label='Sine Wave')
plt.stem(n_sample, signals(n_sample), linefmt='red', label='Sampled Points')
plt.title('Sine Wave')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()
plt.tight_layout()

plt.subplot(2, 1, 2)
plt.plot(n, signals(n), label='Sine Wave')
plt.stem(n_alisging, signals(n_alisging), linefmt='green', label='Aliased Points')
plt.title('Aliased Sine Wave')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()
plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(0, 10, 1)
omega = np.pi
omega1 = np.pi / 4

wave_1 = np.cos(omega * n)
wave_2 = np.cos(omega1 * n)

plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.stem(n , wave_1 , label='Sine Wave with ω = π')
plt.title('Sine Wave with ω = π')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()

plt.subplot(2, 1, 2)
plt.stem(n , wave_2 , label='Sine Wave with ω = π/4', linefmt='orange')
plt.title('Sine Wave with ω = π/4')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def signal(n):
    return 3 * np.cos(100 * np.pi * n)

n = np.arange(0, .2, 0.001)
n_max = np.arange(0, .2, 1/200)
n_min = np.arange(0, .2, 1/75)

plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(n, signal(n), label='Continuous Signal', color='blue')
plt.stem(n_max, signal(n_max), linefmt='red', label='Sampled Max Frequency')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Sampling of Continuous Signal')
plt.grid()
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(n, signal(n), label='Continuous Signal', color='blue')
plt.stem(n_min, signal(n_min), linefmt='red', label='Sampled Min Frequency')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Sampling of Continuous Signal')
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

pi = np.pi
def y(n):
    return 3 * np.cos(200 * pi * n) + 5 * np.sin(600 * pi * n) + 10 * np.cos(1200 * pi * n)

n = np.arange(0, 0.01, 0.00001)
n_mx = np.arange(0, 0.01, 1/5000)
n_mn = np.arange(0, 0.01, 1/2000)

plt.figure(figsize=(10, 5))

plt.subplot(3, 1, 1)
plt.plot(n, y(n), label='Continuous Signal', color='blue')
plt.title('Continuous Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()
plt.tight_layout()

plt.subplot(3, 1, 2)
#plt.plot(n, y(n), label='Continuous Signal', color='blue')
plt.stem(n_mx, y(n_mx), linefmt='red', label='Sampled Max Frequency')
plt.plot(n_mx, y(n_mx), color ='blue')
plt.title('Sampling at Max Frequency')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()
plt.tight_layout()

plt.subplot(3, 1, 3)
#plt.plot(n, y(n), label='Continuous Signal', color='blue')
plt.stem(n_mn, y(n_mn), linefmt='red', label='Sampled Min Frequency')
plt.plot(n_mn, y(n_mn), color='blue')
plt.title('Sampling at Min Frequency')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()
plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def unit_stem(n):
    return np.where(n >= 0, 1, 0)

n = np.arange(0 , 10, 1)

h = unit_stem(n) - unit_stem(n - 5)
x = unit_stem(n)

y = np.convolve(x, h, mode='full')


plt.figure(figsize=(10, 5))
plt.subplot(3, 1, 1)
plt.title("Input Signal x[n]")
plt.stem(n, x)
plt.grid()

plt.subplot(3, 1, 2)
plt.title("Impulse response h[n]")
plt.stem(n, h)
plt.grid()

plt.subplot(3, 1, 3)
plt.title("y[n] = x[n] * h[n]")
plt.stem(np.arange(len(y)), y)
plt.grid()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 3, -2, 4])
y = np.array([2, 3, -1, 3])
z = np.array([2, -1, 4, -2])

c_xy = np.correlate(x, y, mode='full')
c_yz = np.correlate(y, z, mode='full')  # Fixed variable name for clarity

length = np.arange(-len(x) + 1, len(y))  # Fixed the issue by using np.arange

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.stem(length, c_xy)
plt.title('Cross-correlation of x and y')
plt.xlabel('Lag')
plt.ylabel('Correlation Coefficient')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.stem(length, c_xy)
plt.title('Cross-correlation of y and z')
plt.xlabel('Lag')
plt.ylabel('Correlation Coefficient')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
'''
Filter realization using 6-point averaging, 6-point differencing equations. 
'''

import numpy as np
import matplotlib.pyplot as plt

# Sample input signal (analog-like)
np.random.seed(0)
n = np.linspace(0, 1, 200)
x = np.sin(2 * np.pi * 5 * n) + 0.5 * np.random.randn(len(n))  # Sine wave with noise

# 6-point Averaging Filter
def avg_filter(x):
    y = np.zeros_like(x)
    for i in range(5, len(x)):
        y[i] = np.sum(x[i-5:i+1]) / 6
    return y

# 6-point Differencing Filter
def diff_filter(x):
    y = np.zeros_like(x)
    for i in range(5, len(x)):
       y[i] = (x[i] - x[i-1] + x[i-2] - x[i-3] + x[i-4] - x[i-5]) / 6
    return y

plt.figure(figsize=(12, 6))

plt.subplot(3, 1, 1)
plt.plot(n, x, label='Ordinal Signal', color='blue')
plt.title('Input Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(n, avg_filter(x), label='6-point Average Filter', color='blue')
plt.title('Input Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(n, diff_filter(x), label='# 6-point Differencing Filter', color='orange')
plt.title('Output Signal (Filtered)')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()
plt.tight_layout()

plt.show()

# %%
#   Consider a difference equation:
#       y[n] = (1 - a)y[n - 1] + a x[n]

#   Here, x[n] = [1, 2, 2, 10, 2, 2, 1]
#       a --> 0 < a < 1
#   Observation of y[n], effect of a.

import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 2, 10, 2, 2, 1])
n = np.arange(1, len(x) + 1)
a_values = [0.2, 0.5, 0.9]  # Different values of a

def difference_equation(x, a):
    y = [x[0]]
    for n in range(1, len(x)):
        cal = (1 - a) * y[n - 1] + a * x[n]
        y.append(cal)
    return np.array(y)

plt.figure(figsize=(10, 6))
plt.title('Difference Equation Output for Different a Values')
plt.plot(x, label='x[n]', color='gray')
plt.plot(difference_equation(x, a_values[0]), label=f'a = {a_values[0]}', color='red', marker='x')
plt.plot(difference_equation(x, a_values[1]), label=f'a = {a_values[0]}', color='blue', marker='x')
plt.xlabel('n (Index) x[n]')
plt.ylabel('Amplitude')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
"""DFT of xa(t)=sin(2π⋅1000t)+0.5sin(2π⋅2000t+4π). Also IDFT. DFT with window + window function realization."""
import numpy as np
import matplotlib.pyplot as plt
N = 64
n = np.arange(N)
fs = 8000
t = n/fs
def xa(t):
    return np.sin(2000 * np.pi * t) + 0.5 * np.sin(4000 * np.pi * t + 4 * np.pi)
def hanning(N):
    return 0.5 * (1 - np.cos(2 * np.pi * np.arange(N) / (N - 1)))
def dft(x):
    N = len(x)
    X = np.zeros(N, dtype=complex)
    for k in range(N):
        for n in range(N):
            X[k] += x[n] * np.exp(-2j * np.pi * k * n / N)
    return X
def idft(X):
    N = len(X)
    x = np.zeros(N, dtype=complex)
    for n in range(N):
        for k in range(N):
            x[n] += X[k] * np.exp(2j * np.pi * k * n / N)
        x[n] /= N
    return x
    
freq = np.arange(N) * fs / N
x = xa(t)
x_hanning = hanning(N)
hanning_x = x * x_hanning
x_dft = dft(x)
x_hanning_dft = dft(hanning_x)
x_idft = idft(x_dft)
x_idft_hanning = idft(x_hanning_dft)

plt.figure(figsize=(12, 10))

plt.subplot(3, 2, 1)
plt.plot(t, x, label="Original Signal", color="g")
plt.plot(t, hanning_x, label="Hanning Windowed Signal", color="r")
plt.title("Before DFT")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 2)
plt.stem(freq, abs(x_dft), label="Frequency Spectrum")
plt.title("After DFT")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 3)
plt.stem(freq, np.angle(x_hanning_dft, deg=True), label="Hanning Phase Spectrum", linefmt="r", basefmt="r", markerfmt="r")
plt.title("Phase Spectrum After DFT")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 4)
plt.plot(t, x_idft, label="After IDFT", color="g")
plt.plot(t, x_idft_hanning, label="Hanning IDFT", color="r")
plt.title("After IDFT")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 5)
plt.plot(t, x, label="Original Signal", color="g")
plt.plot(t, hanning_x, label="Hanning Windowed Signal", color="r")
plt.title("Before DFT")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /home/noob_coder/Desktop/DSP Lab/my_env/lib/python3.12/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/noob_coder/Desktop/DSP Lab/my_env/lib/python3.12/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
"""DFT of xa(t)=sin(2π⋅1000t)+0.5sin(2π⋅2000t+4π). Also IDFT. DFT with window + window function realization."""

import numpy as np
import matplotlib.pyplot as plt

N = 64
n = np.arange(N)
fs = 8000
t = n/fs
pi = np.pi
def xa(t):
    return np.sin(2 * pi * 1000 * t) + 0.5 * np.sin(2 * pi * 2000 * t + 4 * pi)

def hanning(N):
    return 0.5 * (1 - np.cos(2 * pi * np.arange(N) / (N - 1)))  # Fixed parentheses and array operations

def dft(x):
    y = np.zeros(N, dtype=complex)
    for k in range(N):
        for n in range(N):
            y[k] += x[n] * np.exp(-2j * pi * n * k / N)
    return y

def idft(X):
    y = np.zeros(N, dtype=complex)
    for k in range(N):
        for n in range(N):
            y[k] += X[n] * np.exp(2j * pi * n * k / N)
        y[k] /= N
    return y

freq = np.arange(N) * fs / N
x = xa(t) # Original signal
x_hanning = hanning(N)  # Hanning window
hanning_x = x * x_hanning  # Apply Hanning window
x_dft = dft(x)  # DFT of original signal
x_hanning_dft = dft(hanning_x)  # DFT of Hanning windowed signal


plt.figure(figsize=(12, 10))
plt.subplot(3, 2, 1)
plt.plot(t, x, label="Original Signal", color="g")
plt.plot(t, hanning_x, label="Hanning Windowed Signal", color="r")
plt.title("Before DFT")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 2)
plt.stem(freq, abs(x_dft), label="Frequency Spectrum")
plt.title("After DFT")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 3)
plt.stem(freq, x_hanning, label="Hanning Window", linefmt="r", basefmt="r", markerfmt="r")
plt.ylabel("Phase (degrees)")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 4)
plt.plot(t, idft(x_dft), label="After IDFT", color="g")
plt.plot(t, idft(x_hanning_dft), label="Hanning IDFT", color="r")
plt.title("After IDFT")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 5)
plt.stem(freq, np.angle(x_hanning_dft, deg=True), label="Hanning Phase Spectrum", linefmt="r", basefmt="r", markerfmt="r")
plt.title("Phase Spectrum After DFT")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fs = 500
t = np.arange(0,1,1/fs)
x =  np.sin(2*np.pi*5*t) + 0.5*np.sin(2*np.pi*50*t)

def convolution(x,h):
    len_x = len(x)
    len_h= len(h)
    len_y = len_x+len_h-1
    y = []
    for n in range(len_y):
         sum=0
         for k in range(len_h):
              if 0<=n-k<len_x:
                   sum+=h[k]*x[n-k]
         y.append(sum)
    return y
def hanning(N):
     n = np.arange(N)
     return 0.5-.05*np.cos(2*np.pi*n/N-1)

def lowpassfilter(N,fc,fs):
     n = np.arange(N)
     h = np.sinc(2*fc*(n-((N-1)/2))/fs)*hanning(N)
     h = h / np.sum(h)  # Normalize the filter
     return h
h = lowpassfilter(N=31,fc=10,fs=fs)
y = np.convolve(x, h, mode='same')
t1 = np.arange(len(y))/fs

plt.plot(t,x,label="Noisy Signal",color='r')
plt.plot(t1,y,label="Filtered signal",color="b")
plt.title("FIR Filter")
plt.grid(True)
plt.legend()
plt.show()
